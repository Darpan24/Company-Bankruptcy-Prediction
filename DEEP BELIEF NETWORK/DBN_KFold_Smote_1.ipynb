# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action="ignore")

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import BernoulliRBM
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
#importing data from the dataset
df = pd.read_csv(r"C:\Users\agarw\OneDrive\Desktop\Dissertation\data.csv")

# %%
#checking for bankrupt companies 0 is non-bankrupt and 1 is bankrupt
bankrupt_data = df['Bankrupt?'].value_counts()
bankrupt_data
# Out:
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64

# %%
#Distribution representation
plt.figure(figsize = (10,5))
ax = sns.countplot(df['Bankrupt?'])
ax.bar_label(ax.containers[0])
plt.title('Class Distribution \n (0:Financially Stable || 1:Financially Unstable)', fontsize = 14)
plt.show()

# %%
# seperate the Bankrupt label from the dataset 
y = df['Bankrupt?']
X = df.drop(['Bankrupt?'], axis = 1)

# %%
k_fold = StratifiedKFold(n_splits=8, shuffle=True, random_state=42)

# %%
accuracy_scores = []
precision_scores= []
recall_scores = []
f1_scores = []
confusion_matrices = []

# %%
for train_index, test_index in k_fold.split(X, y):  # X is the feature data, y is the class labels
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    smote = SMOTE(sampling_strategy = 1, random_state=42)
    X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
    
    scaler = StandardScaler()
    
    X_train_resampled = scaler.fit_transform(X_train_resampled)
    X_test = scaler.transform(X_test)
    
    
    model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train_resampled.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),  
    tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    model.fit(X_train_resampled, y_train_resampled, epochs=20, batch_size=32, verbose=2)
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    #Evaluation metrics
    val_accuracy = accuracy_score(y_test, y_pred.round())
    accuracy_scores.append(val_accuracy)
    
    precision = precision_score(y_test, y_pred.round())
    precision_scores.append(precision)
    
    recall = recall_score(y_test, y_pred.round())
    recall_scores.append(recall)
    
    f1_value = f1_score(y_test, y_pred.round())
    f1_scores.append(f1_value)
    
    cm = confusion_matrix(y_test, y_pred.round())
    confusion_matrices.append(cm)
# Out:
# Epoch 1/20
# 361/361 - 1s - loss: 0.2494 - accuracy: 0.9067 - 772ms/epoch - 2ms/step
# Epoch 2/20
# 361/361 - 0s - loss: 0.1394 - accuracy: 0.9526 - 350ms/epoch - 968us/step
# Epoch 3/20
# 361/361 - 0s - loss: 0.0977 - accuracy: 0.9697 - 339ms/epoch - 939us/step
# Epoch 4/20
# 361/361 - 0s - loss: 0.0741 - accuracy: 0.9784 - 338ms/epoch - 936us/step
# Epoch 5/20
# 361/361 - 0s - loss: 0.0582 - accuracy: 0.9837 - 342ms/epoch - 946us/step
# Epoch 6/20
# 361/361 - 0s - loss: 0.0455 - accuracy: 0.9887 - 336ms/epoch - 931us/step
# Epoch 7/20
# 361/361 - 0s - loss: 0.0375 - accuracy: 0.9911 - 337ms/epoch - 933us/step
# Epoch 8/20
# 361/361 - 0s - loss: 0.0304 - accuracy: 0.9926 - 342ms/epoch - 947us/step
# Epoch 9/20
# 361/361 - 0s - loss: 0.0289 - accuracy: 0.9924 - 341ms/epoch - 945us/step
# Epoch 10/20
# 361/361 - 0s - loss: 0.0218 - accuracy: 0.9946 - 338ms/epoch - 936us/step
# Epoch 11/20
# 361/361 - 0s - loss: 0.0148 - accuracy: 0.9964 - 335ms/epoch - 927us/step
# Epoch 12/20
# 361/361 - 0s - loss: 0.0148 - accuracy: 0.9967 - 318ms/epoch - 882us/step
# Epoch 13/20
# 361/361 - 0s - loss: 0.0127 - accuracy: 0.9962 - 329ms/epoch - 911us/step
# Epoch 14/20
# 361/361 - 0s - loss: 0.0091 - accuracy: 0.9975 - 336ms/epoch - 931us/step
# Epoch 15/20
# 361/361 - 0s - loss: 0.0059 - accuracy: 0.9987 - 330ms/epoch - 913us/step
# Epoch 16/20
# 361/361 - 0s - loss: 0.0041 - accuracy: 0.9993 - 317ms/epoch - 877us/step
# Epoch 17/20
# 361/361 - 0s - loss: 0.0034 - accuracy: 0.9996 - 319ms/epoch - 883us/step
# Epoch 18/20
# 361/361 - 0s - loss: 0.0057 - accuracy: 0.9985 - 320ms/epoch - 885us/step
# Epoch 19/20
# 361/361 - 0s - loss: 0.0234 - accuracy: 0.9961 - 316ms/epoch - 876us/step
# Epoch 20/20
# 361/361 - 0s - loss: 0.0142 - accuracy: 0.9966 - 333ms/epoch - 922us/step
# 27/27 [==============================] - 0s 788us/step
# Epoch 1/20
# 361/361 - 1s - loss: 0.2627 - accuracy: 0.8976 - 727ms/epoch - 2ms/step
# Epoch 2/20
# 361/361 - 0s - loss: 0.1483 - accuracy: 0.9485 - 313ms/epoch - 867us/step
# Epoch 3/20
# 361/361 - 0s - loss: 0.1014 - accuracy: 0.9691 - 317ms/epoch - 878us/step
# Epoch 4/20
# 361/361 - 0s - loss: 0.0752 - accuracy: 0.9772 - 321ms/epoch - 889us/step
# Epoch 5/20
# 361/361 - 0s - loss: 0.0573 - accuracy: 0.9838 - 312ms/epoch - 863us/step
# Epoch 6/20
# 361/361 - 0s - loss: 0.0469 - accuracy: 0.9867 - 316ms/epoch - 875us/step
# Epoch 7/20
# 361/361 - 0s - loss: 0.0400 - accuracy: 0.9890 - 313ms/epoch - 868us/step
# Epoch 8/20
# 361/361 - 0s - loss: 0.0312 - accuracy: 0.9924 - 322ms/epoch - 891us/step
# Epoch 9/20
# 361/361 - 0s - loss: 0.0262 - accuracy: 0.9928 - 317ms/epoch - 878us/step
# Epoch 10/20
# 361/361 - 0s - loss: 0.0196 - accuracy: 0.9947 - 313ms/epoch - 867us/step
# Epoch 11/20
# 361/361 - 0s - loss: 0.0204 - accuracy: 0.9944 - 321ms/epoch - 890us/step
# Epoch 12/20
# 361/361 - 0s - loss: 0.0128 - accuracy: 0.9968 - 317ms/epoch - 878us/step
# Epoch 13/20
# 361/361 - 0s - loss: 0.0094 - accuracy: 0.9977 - 315ms/epoch - 874us/step
# Epoch 14/20
# 361/361 - 0s - loss: 0.0141 - accuracy: 0.9960 - 322ms/epoch - 891us/step
# Epoch 15/20
# 361/361 - 0s - loss: 0.0075 - accuracy: 0.9984 - 315ms/epoch - 873us/step
# Epoch 16/20
# 361/361 - 0s - loss: 0.0069 - accuracy: 0.9987 - 324ms/epoch - 897us/step
# Epoch 17/20
# 361/361 - 0s - loss: 0.0100 - accuracy: 0.9977 - 325ms/epoch - 901us/step
# Epoch 18/20
# 361/361 - 0s - loss: 0.0055 - accuracy: 0.9987 - 325ms/epoch - 901us/step
# Epoch 19/20
# 361/361 - 0s - loss: 0.0030 - accuracy: 0.9996 - 318ms/epoch - 880us/step
# Epoch 20/20
# 361/361 - 0s - loss: 0.0016 - accuracy: 0.9999 - 324ms/epoch - 898us/step
# 27/27 [==============================] - 0s 823us/step
# Epoch 1/20
# 361/361 - 1s - loss: 0.2588 - accuracy: 0.8971 - 737ms/epoch - 2ms/step
# Epoch 2/20
# 361/361 - 0s - loss: 0.1522 - accuracy: 0.9479 - 318ms/epoch - 880us/step
# Epoch 3/20
# 361/361 - 0s - loss: 0.1079 - accuracy: 0.9675 - 318ms/epoch - 882us/step
# Epoch 4/20
# 361/361 - 0s - loss: 0.0799 - accuracy: 0.9771 - 314ms/epoch - 870us/step
# Epoch 5/20
# 361/361 - 0s - loss: 0.0622 - accuracy: 0.9835 - 319ms/epoch - 884us/step
# Epoch 6/20
# 361/361 - 0s - loss: 0.0514 - accuracy: 0.9865 - 318ms/epoch - 882us/step
# Epoch 7/20
# 361/361 - 0s - loss: 0.0407 - accuracy: 0.9897 - 312ms/epoch - 865us/step
# Epoch 8/20
# 361/361 - 0s - loss: 0.0340 - accuracy: 0.9909 - 326ms/epoch - 902us/step
# Epoch 9/20
# 361/361 - 0s - loss: 0.0266 - accuracy: 0.9931 - 315ms/epoch - 874us/step
# Epoch 10/20
# 361/361 - 0s - loss: 0.0245 - accuracy: 0.9936 - 315ms/epoch - 873us/step
# Epoch 11/20
# 361/361 - 0s - loss: 0.0170 - accuracy: 0.9957 - 321ms/epoch - 889us/step
# Epoch 12/20
# 361/361 - 0s - loss: 0.0175 - accuracy: 0.9956 - 314ms/epoch - 869us/step
# Epoch 13/20
# 361/361 - 0s - loss: 0.0163 - accuracy: 0.9958 - 319ms/epoch - 885us/step
# Epoch 14/20
# 361/361 - 0s - loss: 0.0087 - accuracy: 0.9983 - 327ms/epoch - 905us/step
# Epoch 15/20
# 361/361 - 0s - loss: 0.0056 - accuracy: 0.9988 - 314ms/epoch - 870us/step
# Epoch 16/20
# 361/361 - 0s - loss: 0.0084 - accuracy: 0.9975 - 315ms/epoch - 872us/step
# Epoch 17/20
# 361/361 - 0s - loss: 0.0107 - accuracy: 0.9963 - 326ms/epoch - 904us/step
# Epoch 18/20
# 361/361 - 0s - loss: 0.0082 - accuracy: 0.9977 - 314ms/epoch - 871us/step
# Epoch 19/20
# 361/361 - 0s - loss: 0.0028 - accuracy: 0.9994 - 319ms/epoch - 885us/step
# Epoch 20/20
# 361/361 - 0s - loss: 0.0017 - accuracy: 0.9999 - 333ms/epoch - 922us/step
# 27/27 [==============================] - 0s 751us/step
# Epoch 1/20
# 361/361 - 1s - loss: 0.2710 - accuracy: 0.8959 - 736ms/epoch - 2ms/step
# Epoch 2/20
# 361/361 - 0s - loss: 0.1618 - accuracy: 0.9448 - 323ms/epoch - 895us/step
# Epoch 3/20
# 361/361 - 0s - loss: 0.1135 - accuracy: 0.9643 - 318ms/epoch - 882us/step
# Epoch 4/20
# 361/361 - 0s - loss: 0.0819 - accuracy: 0.9753 - 322ms/epoch - 891us/step
# Epoch 5/20
# 361/361 - 0s - loss: 0.0622 - accuracy: 0.9835 - 323ms/epoch - 895us/step
# Epoch 6/20
# 361/361 - 0s - loss: 0.0466 - accuracy: 0.9882 - 322ms/epoch - 893us/step
# Epoch 7/20
# 361/361 - 0s - loss: 0.0417 - accuracy: 0.9898 - 317ms/epoch - 877us/step
# Epoch 8/20
# 361/361 - 0s - loss: 0.0330 - accuracy: 0.9908 - 320ms/epoch - 887us/step
# Epoch 9/20
# 361/361 - 0s - loss: 0.0246 - accuracy: 0.9933 - 317ms/epoch - 877us/step
# Epoch 10/20
# 361/361 - 0s - loss: 0.0189 - accuracy: 0.9956 - 320ms/epoch - 887us/step
# Epoch 11/20
# 361/361 - 0s - loss: 0.0192 - accuracy: 0.9941 - 321ms/epoch - 890us/step
# Epoch 12/20
# 361/361 - 0s - loss: 0.0121 - accuracy: 0.9971 - 317ms/epoch - 879us/step
# Epoch 13/20
# 361/361 - 0s - loss: 0.0104 - accuracy: 0.9977 - 318ms/epoch - 881us/step
# Epoch 14/20
# 361/361 - 0s - loss: 0.0131 - accuracy: 0.9963 - 321ms/epoch - 888us/step
# Epoch 15/20
# 361/361 - 0s - loss: 0.0073 - accuracy: 0.9984 - 315ms/epoch - 873us/step
# Epoch 16/20
# 361/361 - 0s - loss: 0.0050 - accuracy: 0.9987 - 323ms/epoch - 896us/step
# Epoch 17/20
# 361/361 - 0s - loss: 0.0038 - accuracy: 0.9993 - 324ms/epoch - 898us/step
# Epoch 18/20
# 361/361 - 0s - loss: 0.0032 - accuracy: 0.9994 - 317ms/epoch - 878us/step
# Epoch 19/20
# 361/361 - 0s - loss: 0.0133 - accuracy: 0.9952 - 325ms/epoch - 900us/step
# Epoch 20/20
# 361/361 - 0s - loss: 0.0054 - accuracy: 0.9988 - 316ms/epoch - 876us/step
# 27/27 [==============================] - 0s 739us/step
# Epoch 1/20
# 361/361 - 1s - loss: 0.2632 - accuracy: 0.8965 - 731ms/epoch - 2ms/step
# Epoch 2/20
# 361/361 - 0s - loss: 0.1558 - accuracy: 0.9454 - 318ms/epoch - 882us/step
# Epoch 3/20
# 361/361 - 0s - loss: 0.1096 - accuracy: 0.9650 - 317ms/epoch - 879us/step
# Epoch 4/20
# 361/361 - 0s - loss: 0.0812 - accuracy: 0.9745 - 316ms/epoch - 874us/step
# Epoch 5/20
# 361/361 - 0s - loss: 0.0626 - accuracy: 0.9808 - 322ms/epoch - 893us/step
# Epoch 6/20
# 361/361 - 0s - loss: 0.0495 - accuracy: 0.9850 - 321ms/epoch - 889us/step
# Epoch 7/20
# 361/361 - 0s - loss: 0.0402 - accuracy: 0.9893 - 321ms/epoch - 890us/step
# Epoch 8/20
# 361/361 - 0s - loss: 0.0311 - accuracy: 0.9915 - 324ms/epoch - 897us/step
# Epoch 9/20
# 361/361 - 0s - loss: 0.0256 - accuracy: 0.9924 - 317ms/epoch - 879us/step
# Epoch 10/20
# 361/361 - 0s - loss: 0.0210 - accuracy: 0.9940 - 322ms/epoch - 891us/step
# Epoch 11/20
# 361/361 - 0s - loss: 0.0162 - accuracy: 0.9951 - 324ms/epoch - 897us/step
# Epoch 12/20
# 361/361 - 0s - loss: 0.0114 - accuracy: 0.9973 - 319ms/epoch - 883us/step
# Epoch 13/20
# 361/361 - 0s - loss: 0.0087 - accuracy: 0.9984 - 329ms/epoch - 912us/step
# Epoch 14/20
# 361/361 - 0s - loss: 0.0082 - accuracy: 0.9977 - 348ms/epoch - 964us/step
# Epoch 15/20
# 361/361 - 0s - loss: 0.0125 - accuracy: 0.9960 - 316ms/epoch - 875us/step
# Epoch 16/20
# 361/361 - 0s - loss: 0.0049 - accuracy: 0.9992 - 320ms/epoch - 887us/step
# Epoch 17/20
# 361/361 - 0s - loss: 0.0060 - accuracy: 0.9983 - 322ms/epoch - 892us/step
# Epoch 18/20
# 361/361 - 0s - loss: 0.0032 - accuracy: 0.9993 - 316ms/epoch - 876us/step
# Epoch 19/20
# 361/361 - 0s - loss: 0.0021 - accuracy: 0.9997 - 320ms/epoch - 886us/step
# Epoch 20/20
# 361/361 - 0s - loss: 0.0016 - accuracy: 0.9997 - 319ms/epoch - 883us/step
# 27/27 [==============================] - 0s 761us/step
# Epoch 1/20
# 361/361 - 1s - loss: 0.2519 - accuracy: 0.9052 - 727ms/epoch - 2ms/step
# Epoch 2/20
# 361/361 - 0s - loss: 0.1438 - accuracy: 0.9535 - 322ms/epoch - 893us/step
# Epoch 3/20
# 361/361 - 0s - loss: 0.0974 - accuracy: 0.9708 - 316ms/epoch - 876us/step
# Epoch 4/20
# 361/361 - 0s - loss: 0.0699 - accuracy: 0.9803 - 323ms/epoch - 896us/step
# Epoch 5/20
# 361/361 - 0s - loss: 0.0528 - accuracy: 0.9861 - 345ms/epoch - 955us/step
# Epoch 6/20
# 361/361 - 0s - loss: 0.0423 - accuracy: 0.9885 - 323ms/epoch - 896us/step
# Epoch 7/20
# 361/361 - 0s - loss: 0.0334 - accuracy: 0.9914 - 319ms/epoch - 885us/step
# Epoch 8/20
# 361/361 - 0s - loss: 0.0268 - accuracy: 0.9930 - 361ms/epoch - 999us/step
# Epoch 9/20
# 361/361 - 0s - loss: 0.0216 - accuracy: 0.9945 - 343ms/epoch - 950us/step
# Epoch 10/20
# 361/361 - 0s - loss: 0.0173 - accuracy: 0.9952 - 320ms/epoch - 888us/step
# Epoch 11/20
# 361/361 - 0s - loss: 0.0157 - accuracy: 0.9958 - 320ms/epoch - 886us/step
# Epoch 12/20
# 361/361 - 0s - loss: 0.0091 - accuracy: 0.9980 - 323ms/epoch - 896us/step
# Epoch 13/20
# 361/361 - 0s - loss: 0.0091 - accuracy: 0.9973 - 317ms/epoch - 877us/step
# Epoch 14/20
# 361/361 - 0s - loss: 0.0077 - accuracy: 0.9976 - 321ms/epoch - 889us/step
# Epoch 15/20
# 361/361 - 0s - loss: 0.0060 - accuracy: 0.9990 - 315ms/epoch - 872us/step
# Epoch 16/20
# 361/361 - 0s - loss: 0.0049 - accuracy: 0.9990 - 317ms/epoch - 879us/step
# Epoch 17/20
# 361/361 - 0s - loss: 0.0023 - accuracy: 0.9998 - 364ms/epoch - 1ms/step
# Epoch 18/20
# 361/361 - 0s - loss: 0.0016 - accuracy: 0.9999 - 422ms/epoch - 1ms/step
# Epoch 19/20
# 361/361 - 0s - loss: 0.0010 - accuracy: 1.0000 - 343ms/epoch - 950us/step
# Epoch 20/20
# 361/361 - 0s - loss: 7.2580e-04 - accuracy: 1.0000 - 322ms/epoch - 891us/step
# 27/27 [==============================] - 0s 747us/step
# Epoch 1/20
# 361/361 - 1s - loss: 0.2562 - accuracy: 0.9032 - 1s/epoch - 4ms/step
# Epoch 2/20
# 361/361 - 0s - loss: 0.1479 - accuracy: 0.9488 - 323ms/epoch - 896us/step
# Epoch 3/20
# 361/361 - 0s - loss: 0.1053 - accuracy: 0.9680 - 320ms/epoch - 887us/step
# Epoch 4/20
# 361/361 - 0s - loss: 0.0804 - accuracy: 0.9758 - 332ms/epoch - 920us/step
# Epoch 5/20
# 361/361 - 0s - loss: 0.0596 - accuracy: 0.9834 - 324ms/epoch - 896us/step
# Epoch 6/20
# 361/361 - 0s - loss: 0.0466 - accuracy: 0.9874 - 321ms/epoch - 889us/step
# Epoch 7/20
# 361/361 - 0s - loss: 0.0373 - accuracy: 0.9897 - 324ms/epoch - 898us/step
# Epoch 8/20
# 361/361 - 0s - loss: 0.0290 - accuracy: 0.9915 - 316ms/epoch - 874us/step
# Epoch 9/20
# 361/361 - 0s - loss: 0.0240 - accuracy: 0.9934 - 318ms/epoch - 882us/step
# Epoch 10/20
# 361/361 - 0s - loss: 0.0186 - accuracy: 0.9955 - 318ms/epoch - 882us/step
# Epoch 11/20
# 361/361 - 0s - loss: 0.0152 - accuracy: 0.9963 - 321ms/epoch - 888us/step
# Epoch 12/20
# 361/361 - 0s - loss: 0.0118 - accuracy: 0.9969 - 329ms/epoch - 911us/step
# Epoch 13/20
# 361/361 - 0s - loss: 0.0097 - accuracy: 0.9975 - 315ms/epoch - 872us/step
# Epoch 14/20
# 361/361 - 0s - loss: 0.0083 - accuracy: 0.9977 - 315ms/epoch - 874us/step
# Epoch 15/20
# 361/361 - 0s - loss: 0.0073 - accuracy: 0.9980 - 321ms/epoch - 889us/step
# Epoch 16/20
# 361/361 - 0s - loss: 0.0040 - accuracy: 0.9990 - 315ms/epoch - 872us/step
# Epoch 17/20
# 361/361 - 0s - loss: 0.0028 - accuracy: 0.9994 - 322ms/epoch - 893us/step
# Epoch 18/20
# 361/361 - 0s - loss: 0.0018 - accuracy: 1.0000 - 321ms/epoch - 888us/step
# Epoch 19/20
# 361/361 - 0s - loss: 0.0013 - accuracy: 1.0000 - 319ms/epoch - 884us/step
# Epoch 20/20
# 361/361 - 0s - loss: 8.0662e-04 - accuracy: 1.0000 - 318ms/epoch - 880us/step
# 27/27 [==============================] - 0s 729us/step
# Epoch 1/20
# 361/361 - 1s - loss: 0.2686 - accuracy: 0.9001 - 755ms/epoch - 2ms/step
# Epoch 2/20
# 361/361 - 0s - loss: 0.1596 - accuracy: 0.9440 - 321ms/epoch - 890us/step
# Epoch 3/20
# 361/361 - 0s - loss: 0.1099 - accuracy: 0.9674 - 318ms/epoch - 882us/step
# Epoch 4/20
# 361/361 - 0s - loss: 0.0787 - accuracy: 0.9776 - 320ms/epoch - 887us/step
# Epoch 5/20
# 361/361 - 0s - loss: 0.0617 - accuracy: 0.9832 - 320ms/epoch - 887us/step
# Epoch 6/20
# 361/361 - 0s - loss: 0.0487 - accuracy: 0.9862 - 323ms/epoch - 894us/step
# Epoch 7/20
# 361/361 - 0s - loss: 0.0367 - accuracy: 0.9904 - 318ms/epoch - 880us/step
# Epoch 8/20
# 361/361 - 0s - loss: 0.0309 - accuracy: 0.9919 - 316ms/epoch - 875us/step
# Epoch 9/20
# 361/361 - 0s - loss: 0.0247 - accuracy: 0.9937 - 320ms/epoch - 886us/step
# Epoch 10/20
# 361/361 - 0s - loss: 0.0190 - accuracy: 0.9957 - 316ms/epoch - 875us/step
# Epoch 11/20
# 361/361 - 0s - loss: 0.0179 - accuracy: 0.9958 - 317ms/epoch - 878us/step
# Epoch 12/20
# 361/361 - 0s - loss: 0.0141 - accuracy: 0.9964 - 319ms/epoch - 883us/step
# Epoch 13/20
# 361/361 - 0s - loss: 0.0099 - accuracy: 0.9974 - 318ms/epoch - 880us/step
# Epoch 14/20
# 361/361 - 0s - loss: 0.0077 - accuracy: 0.9982 - 319ms/epoch - 884us/step
# Epoch 15/20
# 361/361 - 0s - loss: 0.0121 - accuracy: 0.9964 - 322ms/epoch - 893us/step
# Epoch 16/20
# 361/361 - 0s - loss: 0.0117 - accuracy: 0.9970 - 320ms/epoch - 886us/step
# Epoch 17/20
# 361/361 - 0s - loss: 0.0061 - accuracy: 0.9984 - 318ms/epoch - 881us/step
# Epoch 18/20
# 361/361 - 0s - loss: 0.0028 - accuracy: 0.9997 - 319ms/epoch - 882us/step
# Epoch 19/20
# 361/361 - 0s - loss: 0.0019 - accuracy: 0.9997 - 315ms/epoch - 873us/step
# Epoch 20/20
# 361/361 - 0s - loss: 0.0013 - accuracy: 1.0000 - 316ms/epoch - 875us/step
# 27/27 [==============================] - 0s 741us/step
# average_validation_accuracy :  0.9617256341880907
# average_precision_accuracy :  0.3915960723076497
# average_recall_accuracy :  0.3645833333333333
# average_f1_value_accuracy :  0.36979240705759897
# average_confusion_matrix :  [[6478  121]
#  [ 140   80]]

# %%
average_validation_accuracy = np.mean(accuracy_scores)
print("average_validation_accuracy : ",average_validation_accuracy)

average_precision_accuracy = np.mean(precision_scores)
print("average_precision_accuracy : ",average_precision_accuracy)

average_recall_accuracy = np.mean(recall_scores)
print("average_recall_accuracy : ",average_recall_accuracy)

average_f1_value_accuracy = np.mean(f1_scores)
print("average_f1_value_accuracy : ",average_f1_value_accuracy)

average_confusion_matrix = sum(confusion_matrices)
print("average_confusion_matrix : ",average_confusion_matrix)
# Out:
# average_validation_accuracy :  0.9617256341880907
# average_precision_accuracy :  0.3915960723076497
# average_recall_accuracy :  0.3645833333333333
# average_f1_value_accuracy :  0.36979240705759897
# average_confusion_matrix :  [[6478  121]
#  [ 140   80]]
